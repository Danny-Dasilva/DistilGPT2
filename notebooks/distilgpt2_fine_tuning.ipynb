# %% [markdown]
# <a href="https://colab.research.google.com/github/Danny-Dasilva/DistilGPT2/blob/main/notebooks/distilgpt2_fine_tuning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Do NOT RUN THIS FIRST CELL,

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %% [markdown]
# #Start Here for quick test

# %%
# !wget https://raw.githubusercontent.com/Danny-Dasilva/gpt2/32b1ddd103e73179330dda2b2b5c30ca88f2bc43/training.txt
# Out:
# --2021-04-21 19:56:29--  https://raw.githubusercontent.com/Danny-Dasilva/gpt2/32b1ddd103e73179330dda2b2b5c30ca88f2bc43/training.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.110.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 66296 (65K) [text/plain]
# Saving to: ‘training.txt’
#
# training.txt        100%[===================>]  64.74K  --.-KB/s    in 0.007s
#
# 2021-04-21 19:56:30 (8.84 MB/s) - ‘training.txt’ saved [66296/66296]

# %%
# !cat training.txt
# Out:
# as in 4 different people in a 4 corner stage metamorphic rotation - never more than 1 corner at same time.
# <|endoftext|>
# Academic scientists created over 77,000 tons of atomic  waste and more everyday - for your children's future.
# <|endoftext|>
# Self is below the family form of 4-corner metamorphosis.
# <|endoftext|>
# Students must stop such evil, or perish.
# <|endoftext|>
# Media people are evil liars.
# <|endoftext|>
# Time Cube discovery makes me wiser than human/gods.
# <|endoftext|>
# You are evil word worshiper.
# <|endoftext|>
# Rotate Earth 1/4 turn
# <|endoftext|>
# I plan to sue academic institutions for multi- millions of dollars
# <|endoftext|>
# USA on a path to cannibalism.
# <|endoftext|>
# Human word animals are singularity stupid.
# <|endoftext|>
# Educators are"damn liars",and most evil of all animals.
# <|endoftext|>
# Socrates has a sun-up
# <|endoftext|>
# * 4 days in only 1 Earth rotation.
# <|endoftext|>
# * 4 simultaneous years of the seasons.
# ...

# %%
# !git clone https://github.com/huggingface/transformers.git
# Out:
# Cloning into 'transformers'...
# remote: Enumerating objects: 70713, done.
# remote: Counting objects: 100% (799/799), done.
# remote: Compressing objects: 100% (434/434), done.
# remote: Total 70713 (delta 408), reused 634 (delta 303), pack-reused 69914
# Receiving objects: 100% (70713/70713), 53.85 MiB | 17.95 MiB/s, done.
# Resolving deltas: 100% (49978/49978), done.

# %%
# !pip install -q ./transformers
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
#      |████████████████████████████████| 3.3MB 8.5MB/s
#      |████████████████████████████████| 901kB 55.2MB/s
# ...

# %%
# !pip install datasets
# Out:
# ...
#      |████████████████████████████████| 204kB 7.5MB/s
# ...
#      |████████████████████████████████| 112kB 12.9MB/s
# ...
#      |████████████████████████████████| 245kB 10.5MB/s
# ...

# %%
weights_dir = "output"

# %%
file_name = "training.txt"

# %%
num_epochs = 20 # I tried less but it seems the number on the batch correlates to normal gpt numbers, and it usualy takes till around 700-1000 for the model to be good

# %%
# !ls transformers/
# Out:
# CODE_OF_CONDUCT.md  hubconf.py	 model_cards	 setup.cfg  utils
# CONTRIBUTING.md     ISSUES.md	 notebooks	 setup.py   valohai.yaml
# docker		    LICENSE	 pyproject.toml  src
# docs		    Makefile	 README.md	 templates
# examples	    MANIFEST.in  scripts	 tests

# %%
cmd = f'''
python transformers/examples/pytorch/language-modeling/run_clm.py \
    --model_name_or_path distilgpt2 \
    --train_file {file_name} \
    --do_train \
    --num_train_epochs {num_epochs} \
    --overwrite_output_dir \
    --per_device_train_batch_size 2 \
    --output_dir {weights_dir}
'''

# %%
# !{cmd}
# Out:
# 2021-04-21 20:20:53.249145: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 04/21/2021 20:20:54 - WARNING - __main__ -   Process rank: -1, device: cuda:0, n_gpu: 1distributed training: False, 16-bits training: False
# ...

# %%
from transformers import GPT2LMHeadModel, GPT2Tokenizer

def get_model_tokenizer(weights_dir, device = 'cuda'):
    print("Loading Model ...")
    model = GPT2LMHeadModel.from_pretrained(weights_dir)
    model.to('cuda')
    print("Model Loaded ...")
    tokenizer = GPT2Tokenizer.from_pretrained(weights_dir)
    return model, tokenizer

def generate_messages(
    model,
    tokenizer,
    prompt_text,
    stop_token,
    length,
    num_return_sequences,
    temperature = 0.7,
    k=20,
    p=0.9,
    repetition_penalty = 1.0,
    device = 'cuda'
):

    MAX_LENGTH = int(10000)
    def adjust_length_to_model(length, max_sequence_length):
        if length < 0 and max_sequence_length > 0:
            length = max_sequence_length
        elif 0 < max_sequence_length < length:
            length = max_sequence_length  # No generation bigger than model size
        elif length < 0:
            length = MAX_LENGTH  # avoid infinite loop
        return length
        
    length = adjust_length_to_model(length=length, max_sequence_length=model.config.max_position_embeddings)

    encoded_prompt = tokenizer.encode(prompt_text, add_special_tokens=False, return_tensors="pt")

    encoded_prompt = encoded_prompt.to(device)

    output_sequences = model.generate(
            input_ids=encoded_prompt,
            max_length=length + len(encoded_prompt[0]),
            temperature=temperature,
            top_k=k,
            top_p=p,
            repetition_penalty=repetition_penalty,
            do_sample=True,
            num_return_sequences=num_return_sequences,
        )

    if len(output_sequences.shape) > 2:
        output_sequences.squeeze_()

    generated_sequences = []

    for generated_sequence_idx, generated_sequence in enumerate(output_sequences):
        #print("=== GENERATED SEQUENCE {} ===".format(generated_sequence_idx + 1))
        generated_sequence = generated_sequence.tolist()

        # Decode text
        text = tokenizer.decode(generated_sequence, clean_up_tokenization_spaces=True)

        # Remove all text after the stop token
        text = text[: text.find(stop_token) if stop_token else None]

        # Add the prompt at the beginning of the sequence. Remove the excess text that was used for pre-processing
        total_sequence = (
            prompt_text + text[len(tokenizer.decode(encoded_prompt[0], clean_up_tokenization_spaces=True)) :]
        )

        generated_sequences.append(total_sequence)
    return generated_sequences

# %%
model, tokenizer = get_model_tokenizer(weights_dir, device = 'cuda')
# Out:
# Loading Model ...
# Model Loaded ...

# %%
temperature = 1.0
k=400
p=0.9
repetition_penalty = 1.0
num_return_sequences = 10
length = 1000
stop_token = '<|endoftext|>' #@param {type:"string"}
prompt_text = "Time Cube" #@param {type:"string"}

# %%
# %%time
generate_messages(
    model,
    tokenizer,
    prompt_text,
    stop_token,
    length,
    num_return_sequences,
    temperature = temperature,
    k=k,
    p=p,
    repetition_penalty = repetition_penalty
)
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# /usr/local/lib/python3.7/dist-packages/transformers/generation_utils.py:965: UserWarning: `max_length` is deprecated in this function, use `stopping_criteria=StoppingCriteriaList(MaxLengthCriteria(max_length=max_length))` instead.
#   UserWarning,
# CPU times: user 9.94 s, sys: 4.24 s, total: 14.2 s
# Wall time: 14.2 s
# ["Time Cube is a living reality within a self-contained universe of'substance' cubes.",
#  'Time Cube Cube.',
#  'Time Cube singularity from another physical universe.',
#  'Time Cube Theory on Earth\nExplain Einstein\'s "Cube" Theory',
#  'Time Cube is a topology cube in which two opposite points are aligned simultaneously.',
#  'Time Cube with three dimensions.',
#  'Time Cube Cube is an armature, rotating, rotating rotation, opposite the Sun.',
# ...
